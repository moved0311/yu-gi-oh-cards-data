# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv('cards.csv')
df
# Out:
#              id        name                          name_en        name_ja  \
# 0          2511    拉比麗斯的狂時鐘                Labrynth Cooclock       白銀の城の狂時計
# 1         10000       萬物創世龍              Ten Thousand Dragon          万物創世龍
# 2         27551        限制再生                    Limit Reverse      リミット・リバース
# 3         32864     第13位埋葬者                   The 13th Grave       １３人目の埋葬者
# 4         35699  SPYRAL-龍捲風                   SPYRAL Sleeper  SPYRAL－ボルテックス
# ...         ...         ...                              ...            ...
# 12444  99940363       帝王的凍氣      Frost Blast of the Monarchs          帝王の凍気
# 12445  99946920      魔龍星-饕餮  Taotie, Shadow of the Yang Zing       魔竜星－トウテツ
# 12446  99984170     RESCUE！                          RESCUE!        RESCUE！
# 12447  99991455      霸雷星 雷神        Raijin the Breakbolt Star        覇雷星ライジン
# 12448  99995595        電池回收              Recycling Batteries     バッテリーリサイクル
#
# ...

# %%
filePath = './details/cards.json'
df.to_json(filePath, orient='records')
